# %% [markdown]
# NETFLIX STOCK PRICE PREDICTION MODEL

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,r2_score

# %% [markdown]
# READING THE DATASET

# %%
df = pd.read_csv(r'C:\Users\KIIT\Downloads\NFLX (1).csv')

# %%
cpy_df = df.copy()

# %% [markdown]
# VIEWING THE DATASET

# %%
df.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.tail(5)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %% [markdown]
# TRAINING AND TESTING THE MODEL

# %%
train, test = train_test_split(df, test_size= 0.20)

# %%
test_pred = test.copy()

# %%
train.head(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 818  2021-05-06  495.989990  499.549988  491.369995  499.549988  499.549988
# 320  2019-05-15  343.339996  356.500000  341.390015  354.989990  354.989990
# 127  2018-08-07  353.230011  357.309998  349.010010  351.829987  351.829987
# 867  2021-07-16  541.809998  544.059998  527.049988  530.309998  530.309998
# 15   2018-02-27  294.769989  297.359985  290.589996  290.609985  290.609985
# 429  2019-10-18  289.359985  290.899994  273.359985  275.299988  275.299988
# 352  2019-07-01  373.500000  376.660004  372.000000  374.600006  374.600006
# 249  2019-02-01  337.179993  346.839996  336.500000  339.850006  339.850006
# 64   2018-05-08  325.899994  327.350006  323.049988  326.890015  326.890015
# 905  2021-09-09  606.469971  609.440002  596.549988  597.539978  597.539978
#
#        Volume
# 818   3783700
# 320   6340100
# 127   7970900
# 867   3442100
# 15    9416500
# 429  23429900
# 352   4992600
# 249   9827800
# 64    4735700
# 905   2954200

# %%
test.head(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 865  2021-07-14  541.010010  554.099976  541.010010  547.950012  547.950012
# 403  2019-09-12  288.100006  292.730011  286.600006  288.859985  288.859985
# 405  2019-09-16  294.230011  297.429993  289.779999  294.290009  294.290009
# 901  2021-09-02  583.679993  598.760010  583.679993  588.549988  588.549988
# 214  2018-12-11  274.079987  274.500000  262.760010  265.320007  265.320007
# 911  2021-09-17  587.849976  590.280029  580.849976  589.349976  589.349976
# 779  2021-03-11  512.200012  530.239990  510.709991  523.059998  523.059998
# 492  2020-01-21  340.000000  341.000000  332.589996  338.109985  338.109985
# 169  2018-10-05  359.769989  363.500000  343.000000  351.350006  351.350006
# 431  2019-10-22  271.160004  275.410004  265.799988  266.690002  266.690002
#
#        Volume
# 865   4659500
# 403   5010900
# 405   5307400
# 901   6179900
# 214   9843200
# 911   4145100
# 779   4714500
# 492  14350300
# 169  13523000
# 431  11802400

# %%
plt.hist(df.Open)
# Out:
# (array([ 57., 170., 251.,  87.,  49., 141., 151.,  41.,  34.,  28.]),
#  array([233.919998 , 279.7629958, 325.6059936, 371.4489914, 417.2919892,
#         463.134987 , 508.9779848, 554.8209826, 600.6639804, 646.5069782,
#         692.349976 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Volume)
# Out:
# (array([589., 291.,  85.,  32.,   4.,   5.,   1.,   0.,   0.,   2.]),
#  array([ 1144000.,  6920030., 12696060., 18472090., 24248120., 30024150.,
#         35800180., 41576210., 47352240., 53128270., 58904300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Close)
# Out:
# (array([ 56., 171., 257.,  79.,  50., 138., 153.,  42.,  37.,  26.]),
#  array([233.880005 , 279.6610047, 325.4420044, 371.2230041, 417.0040038,
#         462.7850035, 508.5660032, 554.3470029, 600.1280026, 645.9090023,
#         691.690002 ]),
#  <BarContainer object of 10 artists>)

# %%
x_train = train[['Open', 'High', 'Low', 'Volume']].values
x_test = test[['Open', 'High', 'Low', 'Volume']].values

# %%
y_train = train['Close'].values
y_test = test['Close'].values

# %%
def style():
    plt.figure(facecolor='black', figsize=(9,4))
    ax = plt.axes()

    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to white
    ax.tick_params(axis='y', colors='white')    #setting up Y-axis tick color to white

    ax.spines['left'].set_color('white')        #setting up Y-axis spine color to white
    #ax.spines['right'].set_color('white')
    #ax.spines['top'].set_color('white')
    ax.spines['bottom'].set_color('white')      #setting up X-axis spine color to white

    ax.set_facecolor("black")

# %%
cpy_df['Date']=pd.to_datetime(cpy_df['Date'],format='%Y-%m-%d')

# %%
data = pd.DataFrame(cpy_df[['Date','Close']])
data=data.reset_index()
data=data.drop('index',axis=1)
data.set_index('Date', inplace=True)
data = data.asfreq('D')
data
# Out:
#                  Close
# Date
# 2018-02-05  254.259995
# 2018-02-06  265.720001
# 2018-02-07  264.559998
# 2018-02-08  250.100006
# 2018-02-09  249.470001
# ...                ...
# 2022-01-31  427.140015
# 2022-02-01  457.130005
# 2022-02-02  429.480011
# 2022-02-03  405.600006
# 2022-02-04  410.170013
#
# [1461 rows x 1 columns]

# %% [markdown]
# CLOSE PRICE DATA VISUALISATION

# %%
style()
plt.title('Closing Stock Price', color="white")
plt.plot(cpy_df.Date, cpy_df.Close, color="#94F008")
plt.legend(["Close"], loc ="lower right", facecolor='black', labelcolor='white')

# %% [markdown]
# DECISION TREE REGRESSOR MODEL

# %%
dtr = DecisionTreeRegressor(max_depth= 4)
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
dtr_pred = dtr.predict(x_test)
dtr_pred
# Out:
# array([537.82183529, 278.65595702, 278.65595702, 606.43299812,
#        278.65595702, 606.43299812, 537.82183529, 360.6257395 ,
#        360.6257395 , 278.65595702, 416.4016016 , 416.4016016 ,
#        667.7244965 , 360.6257395 , 416.4016016 , 493.62979883,
#        360.6257395 , 360.6257395 , 537.82183529, 493.62979883,
#        416.4016016 , 278.65595702, 278.65595702, 316.75549453,
#        416.4016016 , 316.75549453, 606.43299812, 316.75549453,
#        278.65595702, 537.82183529, 537.82183529, 606.43299812,
#        493.62979883, 360.6257395 , 360.6257395 , 606.43299812,
#        537.82183529, 537.82183529, 316.75549453, 316.75549453,
#        278.65595702, 360.6257395 , 316.75549453, 360.6257395 ,
#        360.6257395 , 316.75549453, 537.82183529, 537.82183529,
#        278.65595702, 360.6257395 , 316.75549453, 493.62979883,
#        360.6257395 , 278.65595702, 493.62979883, 278.65595702,
#        360.6257395 , 493.62979883, 493.62979883, 360.6257395 ,
#        278.65595702, 360.6257395 , 537.82183529, 316.75549453,
#        278.65595702, 537.82183529, 360.6257395 , 606.43299812,
#        360.6257395 , 316.75549453, 493.62979883, 360.6257395 ,
#        493.62979883, 537.82183529, 360.6257395 , 493.62979883,
#        278.65595702, 493.62979883, 360.6257395 , 493.62979883,
#        416.4016016 , 493.62979883, 278.65595702, 667.7244965 ,
#        493.62979883, 278.65595702, 278.65595702, 667.7244965 ,
#        493.62979883, 316.75549453, 316.75549453, 493.62979883,
#        493.62979883, 606.43299812, 493.62979883, 316.75549453,
#        278.65595702, 537.82183529, 493.62979883, 493.62979883,
#        493.62979883, 606.43299812, 360.6257395 , 537.82183529,
#        360.6257395 , 493.62979883, 360.6257395 , 278.65595702,
#        493.62979883, 493.62979883, 360.6257395 , 278.65595702,
#        493.62979883, 493.62979883, 278.65595702, 278.65595702,
#        316.75549453, 316.75549453, 360.6257395 , 278.65595702,
#        537.82183529, 537.82183529, 493.62979883, 416.4016016 ,
#        493.62979883, 360.6257395 , 316.75549453, 278.65595702,
#        606.43299812, 416.4016016 , 493.62979883, 416.4016016 ,
#        278.65595702, 493.62979883, 278.65595702, 360.6257395 ,
#        360.6257395 , 360.6257395 , 316.75549453, 537.82183529,
#        537.82183529, 416.4016016 , 537.82183529, 278.65595702,
#        360.6257395 , 360.6257395 , 316.75549453, 316.75549453,
#        606.43299812, 316.75549453, 493.62979883, 537.82183529,
#        493.62979883, 360.6257395 , 360.6257395 , 278.65595702,
#        416.4016016 , 360.6257395 , 493.62979883, 537.82183529,
#        493.62979883, 493.62979883, 360.6257395 , 416.4016016 ,
#        360.6257395 , 493.62979883, 360.6257395 , 360.6257395 ,
#        493.62979883, 316.75549453, 537.82183529, 316.75549453,
#        316.75549453, 278.65595702, 278.65595702, 360.6257395 ,
#        416.4016016 , 537.82183529, 416.4016016 , 278.65595702,
#        493.62979883, 606.43299812, 537.82183529, 278.65595702,
#        316.75549453, 360.6257395 , 667.7244965 , 360.6257395 ,
#        278.65595702, 667.7244965 , 667.7244965 , 360.6257395 ,
#        316.75549453, 278.65595702, 360.6257395 , 493.62979883,
#        360.6257395 , 493.62979883, 360.6257395 , 278.65595702,
#        667.7244965 , 493.62979883])

# %% [markdown]
# DATA VISUALIZATION OF DECISION TREE REGRESSION MODEL PREDICTED PRICE.

# %%
plt.figure(figsize=(11,5))
plt.plot(dtr_pred)
plt.ylabel('Stock Price')
# Out:
# Text(0, 0.5, 'Stock Price')

# %% [markdown]
# DECISION TREE REGRESSOR MODEL EVALUATION

# %%
print("MSE",round(mean_squared_error(y_test,dtr_pred), 3))
print("RMSE",round(np.sqrt(mean_squared_error(y_test,dtr_pred)), 3))
print("MAE",round(mean_absolute_error(y_test,dtr_pred), 3))
print("MAPE",round(mean_absolute_percentage_error(y_test,dtr_pred), 3))
print("R2 Score : ", round(r2_score(y_test,dtr_pred), 3))
# Out:
# MSE 279.025
# RMSE 16.704
# MAE 13.042
# MAPE 0.033
# R2 Score :  0.978

# %% [markdown]
# DECISION TREE REGRESSION MODEL VS ACTUAL DATA VISUALISATION

# %%
plt.figure(figsize=(13,5))
plt.plot(y_test, label='Actual Price')
plt.plot(dtr_pred, label='Predicted Price')
plt.xlabel('Sample Index')
plt.ylabel('Price')
plt.title('Actual vs Predicted Price')
plt.legend()
plt.show()

# %%
plt.scatter(dtr_pred, y_test, color='red', marker='o')
plt.scatter(y_test, y_test, color='blue')
plt.plot(y_test, y_test, color='lime')

# %% [markdown]
# LINEAR REGRESSION MODEL

# %%
lrm = LinearRegression()
lrm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lrm_pred = lrm.predict(x_test)
lrm_pred
# Out:
# array([551.5733147 , 290.81957394, 293.46506258, 595.93275411,
#        265.94647607, 584.4807304 , 525.32681773, 335.9612212 ,
#        350.09205227, 271.02362084, 405.24957996, 392.16780586,
#        685.261626  , 344.64260958, 417.00534451, 485.46445395,
#        355.84248388, 351.85909558, 539.40595486, 488.14148466,
#        422.9818247 , 285.54871168, 269.97936231, 332.8768874 ,
#        402.3024856 , 313.87922959, 578.59474885, 310.02343626,
#        267.82191733, 554.83582848, 548.64956842, 648.8789253 ,
#        492.71065902, 379.05934441, 342.64568407, 593.19126326,
#        582.83295048, 545.02649429, 325.97456086, 321.62290971,
#        286.3846948 , 362.37050786, 323.07719685, 370.40662783,
#        338.05051755, 331.92122327, 540.98882483, 533.00869892,
#        284.32697023, 346.32834658, 300.30896726, 434.7243088 ,
#        350.05968183, 297.88053593, 500.32531339, 280.6122904 ,
#        341.74306102, 441.58991108, 447.59862058, 357.73160658,
#        285.53143527, 365.07009972, 548.06294852, 328.8473701 ,
#        279.88653805, 527.51752846, 382.24761156, 586.04167001,
#        365.71560964, 301.39306102, 484.7885609 , 366.75046392,
#        460.04500434, 518.84690613, 355.49270565, 449.49350473,
#        271.95878771, 508.26641939, 341.96396176, 516.44308027,
#        411.54750807, 501.63796892, 296.40059826, 649.77236344,
#        499.00087995, 284.67227765, 286.43975048, 676.77982299,
#        516.16962856, 307.51655188, 312.00419156, 499.06005707,
#        482.62236756, 637.08121012, 481.33453277, 324.22683945,
#        297.31054996, 533.41594938, 515.44592764, 509.01891359,
#        501.43928732, 639.29871505, 352.79375925, 551.17009256,
#        361.12694358, 468.44571132, 341.09021748, 268.48942394,
#        484.63182946, 490.77941613, 360.31965101, 292.75617618,
#        486.15684956, 502.19757278, 290.74893913, 283.64310168,
#        324.32537169, 334.20218034, 337.647477  , 271.55136366,
#        527.58093264, 543.03985024, 515.11005825, 439.71541353,
#        504.1084032 , 330.50061502, 334.16329712, 306.8022266 ,
#        626.67082386, 422.91079341, 490.37381576, 399.67957265,
#        275.52913954, 455.75241213, 277.36954272, 365.28510678,
#        356.21032624, 379.18594741, 330.8885862 , 528.64440032,
#        534.78204549, 415.53927555, 531.89725702, 265.47299944,
#        341.37987396, 353.38437376, 328.37396639, 299.11927995,
#        586.50284376, 324.63588748, 483.98465033, 513.43523738,
#        502.37533089, 365.03480278, 353.61347285, 288.37821879,
#        419.93136051, 365.82047197, 484.60740132, 527.61663192,
#        485.44832338, 485.23913063, 362.06813478, 415.42144159,
#        354.85768495, 502.51313142, 355.2275698 , 345.48871526,
#        488.50213719, 308.44168374, 537.4335357 , 300.74057991,
#        307.76549415, 297.77313725, 276.997167  , 333.46580593,
#        442.79674289, 534.9321692 , 418.09574049, 272.37273287,
#        505.71301234, 609.82584306, 529.63906904, 291.04512747,
#        334.56132906, 356.67825828, 679.9698189 , 331.05676975,
#        273.7041122 , 663.00817964, 673.48414021, 334.95547586,
#        333.48794372, 261.96572848, 378.37162127, 449.74736964,
#        379.91411505, 500.61843339, 351.07415176, 294.44455186,
#        662.18565155, 482.63157244])

# %% [markdown]
# LINEAR REGRESSION MODEL EVALUATION

# %%
print("MSE",round(mean_squared_error(y_test,lrm_pred), 3))
print("RMSE",round(np.sqrt(mean_squared_error(y_test,lrm_pred)), 3))
print("MAE",round(mean_absolute_error(y_test,lrm_pred), 3))
print("MAPE",round(mean_absolute_percentage_error(y_test,lrm_pred), 3))
print("R2 Score : ", round(r2_score(y_test,lrm_pred), 3))
# Out:
# MSE 11.616
# RMSE 3.408
# MAE 2.711
# MAPE 0.007
# R2 Score :  0.999

# %%
plt.figure(figsize=(11,5))
plt.plot(lrm_pred)

# %% [markdown]
# PREDICTED PRICE DATA VISUALISATION USING LINEAR REGRESSION.

# %%
style()

plt.scatter(lrm_pred, y_test, color='red', marker='o')
plt.scatter(y_test, y_test, color='blue')
plt.plot(y_test, y_test, color='lime')

# %%
test_pred['lrm_Prediction'] = lrm_pred
test_pred
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 865  2021-07-14  541.010010  554.099976  541.010010  547.950012  547.950012
# 403  2019-09-12  288.100006  292.730011  286.600006  288.859985  288.859985
# 405  2019-09-16  294.230011  297.429993  289.779999  294.290009  294.290009
# 901  2021-09-02  583.679993  598.760010  583.679993  588.549988  588.549988
# 214  2018-12-11  274.079987  274.500000  262.760010  265.320007  265.320007
# ..          ...         ...         ...         ...         ...         ...
# 718  2020-12-10  494.559998  503.769989  492.910004  501.089996  501.089996
# 326  2019-05-23  355.500000  357.420013  347.700012  352.209991  352.209991
# 445  2019-11-11  289.160004  296.359985  288.500000  294.179993  294.179993
# 950  2021-11-11  650.239990  665.820007  649.710022  657.580017  657.580017
# 621  2020-07-24  468.769989  487.170013  467.540009  480.450012  480.450012
#
#       Volume  lrm_Prediction
# 865  4659500      551.573315
# 403  5010900      290.819574
# 405  5307400      293.465063
# 901  6179900      595.932754
# 214  9843200      265.946476
# ..       ...             ...
# 718  3018200      500.618433
# 326  5630400      351.074152
# 445  3944300      294.444552
# 950  2868300      662.185652
# 621  7746200      482.631572
#
# [202 rows x 8 columns]

# %%
test_pred[['Close', 'lrm_Prediction']].describe().T
# Out:
#                 count        mean         std         min         25%  \
# Close           202.0  415.026782  111.734998  258.820007  325.439995
# lrm_Prediction  202.0  415.476445  111.480007  261.965728  326.574412
#
#                        50%         75%         max
# Close           377.510010  502.297485  687.400024
# lrm_Prediction  378.715483  502.478681  685.261626

# %% [markdown]
# TEST DATASET SHOWING THE CLOSING VALUE, LRM_PREDICTED VALUE & DRM_PREDICTED VALUES.

# %%
test_pred['drm_prediction'] = dtr_pred
test_pred
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 865  2021-07-14  541.010010  554.099976  541.010010  547.950012  547.950012
# 403  2019-09-12  288.100006  292.730011  286.600006  288.859985  288.859985
# 405  2019-09-16  294.230011  297.429993  289.779999  294.290009  294.290009
# 901  2021-09-02  583.679993  598.760010  583.679993  588.549988  588.549988
# 214  2018-12-11  274.079987  274.500000  262.760010  265.320007  265.320007
# ..          ...         ...         ...         ...         ...         ...
# 718  2020-12-10  494.559998  503.769989  492.910004  501.089996  501.089996
# 326  2019-05-23  355.500000  357.420013  347.700012  352.209991  352.209991
# 445  2019-11-11  289.160004  296.359985  288.500000  294.179993  294.179993
# 950  2021-11-11  650.239990  665.820007  649.710022  657.580017  657.580017
# 621  2020-07-24  468.769989  487.170013  467.540009  480.450012  480.450012
#
#       Volume  lrm_Prediction  drm_prediction
# 865  4659500      551.573315      551.794783
# 403  5010900      290.819574      290.016666
# 405  5307400      293.465063      290.016666
# 901  6179900      595.932754      592.903599
# 214  9843200      265.946476      265.181628
# ..       ...             ...             ...
# 718  3018200      500.618433      500.345881
# 326  5630400      351.074152      347.908792
# 445  3944300      294.444552      290.016666
# 950  2868300      662.185652      657.887497
# 621  7746200      482.631572      467.848710
#
# [202 rows x 9 columns]

# %% [markdown]
# COMPARISON OF BOTH THE MODELS

# %%
test_pred[['lrm_Prediction','drm_prediction']].describe().T
# Out:
#                 count        mean         std         min         25%  \
# lrm_Prediction  202.0  415.476445  111.480007  261.965728  326.574412
# drm_prediction  202.0  414.637172  111.493657  265.181628  323.976884
#
#                        50%         75%         max
# lrm_Prediction  378.715483  502.478681  685.261626
# drm_prediction  369.392726  500.345881  682.479996

# %% [markdown]
# LINAER REGRESSION MODEL VS ACTUAL PRICE VISUALISATION

# %%
plt.figure(figsize=(13,5))
plt.plot(y_test, label='Actual Price')
plt.plot(lrm_pred, label='Predicted Price')
plt.xlabel('Sample Index')
plt.ylabel('Price')
plt.title('Actual vs Predicted Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(lrm_pred, label='price by linear regression')
plt.plot(dtr_pred, label=' Price by decision tree regressor')
plt.xlabel('Sample Index')
plt.ylabel('Price')
plt.title('Actual vs Predicted Price')
plt.legend()
plt.show()

# %% [markdown]
# COMPARISON OF LINEAR REGRESSION MODEL & DECISION TREE REGRESSION MODEL.

# %%
plt.scatter(dtr_pred, y_test, color='red', marker='o')
plt.scatter(lrm_pred, y_test, color='blue', marker='o')
